# %% [markdown]
# # Image Classification using LENET CNN
#
# ## MNIST Dataset - Handwritten digits(0-9)

# %%
#import tensorflow module
import tensorflow as tf
import numpy as np

print(tf.__version__)
# Out:
# WARNING:tensorflow:From C:\Users\Hardik Gohil\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.15.0

# %% [markdown]
# ## Load the data

# %%
#Grab the MNIST dataset 
print("Downloading MNIST")
(trainData,trainLabels),(testData,testLabels) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading MNIST

# %% [markdown]
# ## Prepare the data

# %%
#parameters for MNIST dataset
num_classes = 10
image_width = 28
image_height = 28
image_channels = 1

# %%
# shape the input data using "channels last" ordering
# num_samples x rows x columns x depth
trainData = trainData.reshape((trainData.shape[0], image_height, image_width, image_channels))
testData = testData.reshape((testData.shape[0], image_height, image_width, image_channels))

# %%
#Scale data to the range of [0,1]
trainData = trainData.astype("float32")/255.0
testData = testData.astype("float32")/255.0

# %%
#Pad the data to 32x32 for use in LENET5 network
trainData = np.pad(trainData,((0,0),(2,2),(2,2),(0,0)),'constant')
testData = np.pad(testData,((0,0),(2,2),(2,2),(0,0)),'constant')

# %%
#display data dimensions
print("TrainData: ", trainData.shape)
print("TrainLabels: ", trainLabels.shape)
print("TestData: ", testData.shape)
print("TestLabels: ", testLabels.shape)
# Out:
# TrainData:  (60000, 32, 32, 1)
# TrainLabels:  (60000,)
# TestData:  (10000, 32, 32, 1)
# TestLabels:  (10000,)

# %%
#parameters for training dataset
num_classes = 10
image_width = 32
image_height = 32
image_channels = 1

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# Import the necessary packages
from tensorflow.keras import backend
from tensorflow.keras import models
from tensorflow.keras import layers

#define the model as a class
class LeNet:
    # Input => CONV => tanh => avg-pool => CONV => tanh => avg-pool => FC => tanh => FC => tanh => FC => SMAX
    @staticmethod
    def init(numChannels,imgRows,imgCols, numClasses,weightsPath = None):
        if backend.image_data_format() == "channels_first":
            inputShape = (numChannels,imgRows,imgCols)
        else:
            inputShape = (imgRows,imgCols,numChannels)
            
        # Initialize the model
        model = models.Sequential()
        
        #define the first set of conv => activation => pool layers
        model.add(layers.Conv2D(filters = 6, kernel_size=(5,5),strides = (1,1), padding = "valid", activation = tf.nn.tanh, input_shape = inputShape))
        model.add(layers.AveragePooling2D(pool_size=(2,2),strides = (2,2)))
        
        #define the second set of conv => activation => pool layers
        model.add(layers.Conv2D(filters = 16, kernel_size=(5,5),strides = (1,1), padding = "valid", activation = tf.nn.tanh, input_shape = inputShape))
        model.add(layers.AveragePooling2D(pool_size=(2,2),strides = (2,2)))
        
        # flatten the convolution volume to fully connected layers
        model.add(layers.Flatten())
        
        # Define the first FC => ACTIVATION layer
        model.add(layers.Dense(units = 120,activation = tf.nn.tanh))

        # Define the second FC => ACTIVATION layer
        model.add(layers.Dense(units = 84,activation = tf.nn.tanh))
        
        #lastly, define the soft-max classifier
        model.add(layers.Dense(units = numClasses, activation = tf.nn.softmax))
        
        # If a weighted path is supplied indicating that the model was pre-trained, then load the weights
        if weightsPath is not None:
            model.load_weights(weightsPath)
            
        return model

# %% [markdown]
# ## Compile Model

# %%
# Initialize the model
model = LeNet.init(numChannels=image_channels,
                  imgRows = image_height,
                  imgCols = image_width,
                  numClasses = num_classes,
                  weightsPath = None)

#Compile Model

model.compile(optimizer = tf.keras.optimizers.SGD(learning_rate=0.01),
              loss = "sparse_categorical_crossentropy",
              metrics = ["accuracy"])
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Hardik Gohil\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 6)         156
#
#  average_pooling2d (Average  (None, 14, 14, 6)         0
#  Pooling2D)
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 16)        2416
#
#  average_pooling2d_1 (Avera  (None, 5, 5, 16)          0
#  gePooling2D)
#
#  flatten (Flatten)           (None, 400)               0
#
#  dense (Dense)               (None, 120)               48120
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dense_2 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 61706 (241.04 KB)
# Trainable params: 61706 (241.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Train Model

# %%
# define callback function for training termination criteria
# accuracy cutoff = 0.99

class myCallBack(tf.keras.callbacks.Callback):
    def on_epoch_end(self,epoch,logs = None):
        if(logs.get("accuracy")>0.99):
            print("\nReached 99% accuracy and so stopped training")
            self.model.stop_training = True

#initialize training criteria
batch_size = 128
epochs = 100

#run training 
print("[INFO] Training..")
history = model.fit(x=trainData,y=trainLabels, validation_data = (testData,testLabels),
                   batch_size=batch_size, epochs=epochs, verbose = 1, callbacks = [myCallBack()])

# There is onl
# Out:
# [INFO] Training..
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\Hardik Gohil\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Hardik Gohil\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 469/469 [==============================] - 5s 9ms/step - loss: 1.1531 - accuracy: 0.7269 - val_loss: 0.5368 - val_accuracy: 0.8731
# Epoch 2/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.4567 - accuracy: 0.8823 - val_loss: 0.3754 - val_accuracy: 0.9000
# Epoch 3/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3585 - accuracy: 0.9016 - val_loss: 0.3158 - val_accuracy: 0.9133
# Epoch 4/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3117 - accuracy: 0.9118 - val_loss: 0.2794 - val_accuracy: 0.9213
# Epoch 5/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2809 - accuracy: 0.9192 - val_loss: 0.2536 - val_accuracy: 0.9271
# Epoch 6/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2570 - accuracy: 0.9257 - val_loss: 0.2345 - val_accuracy: 0.9309
# Epoch 7/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2375 - accuracy: 0.9301 - val_loss: 0.2158 - val_accuracy: 0.9375
# Epoch 8/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2207 - accuracy: 0.9351 - val_loss: 0.2009 - val_accuracy: 0.9409
# Epoch 9/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2062 - accuracy: 0.9389 - val_loss: 0.1881 - val_accuracy: 0.9452
# Epoch 10/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1932 - accuracy: 0.9430 - val_loss: 0.1759 - val_accuracy: 0.9487
# Epoch 11/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1816 - accuracy: 0.9467 - val_loss: 0.1654 - val_accuracy: 0.9509
# Epoch 12/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1711 - accuracy: 0.9496 - val_loss: 0.1551 - val_accuracy: 0.9537
# Epoch 13/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1617 - accuracy: 0.9522 - val_loss: 0.1472 - val_accuracy: 0.9575
# Epoch 14/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1532 - accuracy: 0.9546 - val_loss: 0.1391 - val_accuracy: 0.9586
# Epoch 15/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1454 - accuracy: 0.9571 - val_loss: 0.1331 - val_accuracy: 0.9600
# Epoch 16/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1382 - accuracy: 0.9596 - val_loss: 0.1262 - val_accuracy: 0.9620
# Epoch 17/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1319 - accuracy: 0.9611 - val_loss: 0.1202 - val_accuracy: 0.9647
# Epoch 18/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1258 - accuracy: 0.9628 - val_loss: 0.1150 - val_accuracy: 0.9666
# Epoch 19/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1206 - accuracy: 0.9645 - val_loss: 0.1101 - val_accuracy: 0.9674
# Epoch 20/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1154 - accuracy: 0.9658 - val_loss: 0.1054 - val_accuracy: 0.9690
# Epoch 21/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1109 - accuracy: 0.9680 - val_loss: 0.1014 - val_accuracy: 0.9694
# Epoch 22/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1066 - accuracy: 0.9693 - val_loss: 0.0979 - val_accuracy: 0.9703
# Epoch 23/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1026 - accuracy: 0.9704 - val_loss: 0.0948 - val_accuracy: 0.9721
# Epoch 24/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0990 - accuracy: 0.9716 - val_loss: 0.0924 - val_accuracy: 0.9728
# Epoch 25/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0956 - accuracy: 0.9722 - val_loss: 0.0886 - val_accuracy: 0.9724
# Epoch 26/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0925 - accuracy: 0.9732 - val_loss: 0.0863 - val_accuracy: 0.9746
# Epoch 27/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0895 - accuracy: 0.9740 - val_loss: 0.0836 - val_accuracy: 0.9746
# Epoch 28/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0868 - accuracy: 0.9749 - val_loss: 0.0815 - val_accuracy: 0.9754
# Epoch 29/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0841 - accuracy: 0.9758 - val_loss: 0.0794 - val_accuracy: 0.9763
# Epoch 30/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0818 - accuracy: 0.9763 - val_loss: 0.0769 - val_accuracy: 0.9775
# Epoch 31/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0794 - accuracy: 0.9769 - val_loss: 0.0754 - val_accuracy: 0.9774
# Epoch 32/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0773 - accuracy: 0.9779 - val_loss: 0.0737 - val_accuracy: 0.9789
# Epoch 33/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0753 - accuracy: 0.9782 - val_loss: 0.0715 - val_accuracy: 0.9785
# Epoch 34/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0735 - accuracy: 0.9790 - val_loss: 0.0697 - val_accuracy: 0.9789
# Epoch 35/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0716 - accuracy: 0.9797 - val_loss: 0.0685 - val_accuracy: 0.9797
# Epoch 36/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0699 - accuracy: 0.9802 - val_loss: 0.0669 - val_accuracy: 0.9802
# Epoch 37/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0682 - accuracy: 0.9804 - val_loss: 0.0662 - val_accuracy: 0.9803
# Epoch 38/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0667 - accuracy: 0.9811 - val_loss: 0.0643 - val_accuracy: 0.9805
# Epoch 39/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0651 - accuracy: 0.9816 - val_loss: 0.0637 - val_accuracy: 0.9800
# Epoch 40/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0638 - accuracy: 0.9819 - val_loss: 0.0615 - val_accuracy: 0.9811
# Epoch 41/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0624 - accuracy: 0.9823 - val_loss: 0.0609 - val_accuracy: 0.9820
# Epoch 42/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0611 - accuracy: 0.9829 - val_loss: 0.0598 - val_accuracy: 0.9820
# Epoch 43/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0599 - accuracy: 0.9829 - val_loss: 0.0584 - val_accuracy: 0.9822
# Epoch 44/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0586 - accuracy: 0.9837 - val_loss: 0.0586 - val_accuracy: 0.9826
# Epoch 45/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0576 - accuracy: 0.9836 - val_loss: 0.0570 - val_accuracy: 0.9826
# Epoch 46/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0565 - accuracy: 0.9838 - val_loss: 0.0559 - val_accuracy: 0.9829
# Epoch 47/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0554 - accuracy: 0.9844 - val_loss: 0.0556 - val_accuracy: 0.9832
# Epoch 48/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0545 - accuracy: 0.9844 - val_loss: 0.0548 - val_accuracy: 0.9836
# Epoch 49/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0534 - accuracy: 0.9847 - val_loss: 0.0545 - val_accuracy: 0.9832
# Epoch 50/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0525 - accuracy: 0.9848 - val_loss: 0.0534 - val_accuracy: 0.9833
# Epoch 51/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0516 - accuracy: 0.9855 - val_loss: 0.0522 - val_accuracy: 0.9840
# Epoch 52/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0507 - accuracy: 0.9853 - val_loss: 0.0518 - val_accuracy: 0.9838
# Epoch 53/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0499 - accuracy: 0.9856 - val_loss: 0.0513 - val_accuracy: 0.9844
# Epoch 54/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0490 - accuracy: 0.9858 - val_loss: 0.0505 - val_accuracy: 0.9844
# Epoch 55/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0482 - accuracy: 0.9861 - val_loss: 0.0506 - val_accuracy: 0.9841
# Epoch 56/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0475 - accuracy: 0.9861 - val_loss: 0.0497 - val_accuracy: 0.9842
# Epoch 57/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0467 - accuracy: 0.9866 - val_loss: 0.0487 - val_accuracy: 0.9848
# Epoch 58/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0460 - accuracy: 0.9866 - val_loss: 0.0489 - val_accuracy: 0.9847
# Epoch 59/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0453 - accuracy: 0.9868 - val_loss: 0.0485 - val_accuracy: 0.9848
# Epoch 60/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0446 - accuracy: 0.9872 - val_loss: 0.0474 - val_accuracy: 0.9848
# Epoch 61/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0440 - accuracy: 0.9873 - val_loss: 0.0469 - val_accuracy: 0.9857
# Epoch 62/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0433 - accuracy: 0.9872 - val_loss: 0.0472 - val_accuracy: 0.9852
# Epoch 63/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0427 - accuracy: 0.9877 - val_loss: 0.0465 - val_accuracy: 0.9857
# Epoch 64/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0420 - accuracy: 0.9879 - val_loss: 0.0455 - val_accuracy: 0.9858
# Epoch 65/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0415 - accuracy: 0.9880 - val_loss: 0.0469 - val_accuracy: 0.9847
# Epoch 66/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0409 - accuracy: 0.9880 - val_loss: 0.0455 - val_accuracy: 0.9858
# Epoch 67/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0403 - accuracy: 0.9882 - val_loss: 0.0448 - val_accuracy: 0.9863
# Epoch 68/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0397 - accuracy: 0.9887 - val_loss: 0.0441 - val_accuracy: 0.9859
# Epoch 69/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0392 - accuracy: 0.9885 - val_loss: 0.0436 - val_accuracy: 0.9863
# Epoch 70/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0386 - accuracy: 0.9890 - val_loss: 0.0436 - val_accuracy: 0.9861
# Epoch 71/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0381 - accuracy: 0.9889 - val_loss: 0.0440 - val_accuracy: 0.9858
# Epoch 72/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0377 - accuracy: 0.9892 - val_loss: 0.0429 - val_accuracy: 0.9866
# Epoch 73/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0372 - accuracy: 0.9892 - val_loss: 0.0430 - val_accuracy: 0.9857
# Epoch 74/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0367 - accuracy: 0.9896 - val_loss: 0.0425 - val_accuracy: 0.9865
# Epoch 75/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0362 - accuracy: 0.9893 - val_loss: 0.0424 - val_accuracy: 0.9863
# Epoch 76/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0357 - accuracy: 0.9898 - val_loss: 0.0420 - val_accuracy: 0.9863
# Epoch 77/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0353 - accuracy: 0.9900 - val_loss: 0.0423 - val_accuracy: 0.9862
# Epoch 78/100
# 466/469 [============================>.] - ETA: 0s - loss: 0.0347 - accuracy: 0.9902
# Reached 99% accuracy and so stopped training
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0348 - accuracy: 0.9902 - val_loss: 0.0418 - val_accuracy: 0.9862

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
loss = history.history['loss']

epochs = range(len(acc))

#plot training and val accuracy per epoch
plt.plot(epochs,acc,label = "train_accuracy")
plt.plot(epochs,val_acc,label = "validation_accuracy")
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.legend(loc = "lower right")
plt.title("Training and validation accuracy")
plt.figure()

#plot training and val loss per epoch
plt.plot(epochs,loss,label = "train_loss")
plt.plot(epochs,val_loss,label = "validation_loss")
plt.xlabel("epochs")
plt.ylabel("Loss")
plt.legend(loc = "lower right")
plt.title("Training and validation loss")
plt.figure()

# %%
# show the accuracy on the testing set
print("[INFO] Evaluating...")
(loss,accuracy)= model.evaluate(testData, testLabels, batch_size = batch_size, verbose=1)
print("[INFO] Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# [INFO] Evaluating...
# 79/79 [==============================] - 0s 3ms/step - loss: 0.0418 - accuracy: 0.9862
# [INFO] Accuracy: 98.62%

# %%
model.save_weights("weights/LeNetMNIST.temp.hdf5", overwrite = True)

# %% [markdown]
# ## Evaluate pre trained model

# %%
# init model and load the model weights
print("[INFO] compiling model")
model = LeNet.init(numChannels=image_channels,
                  imgRows = image_height,
                  imgCols = image_width,
                  numClasses = num_classes,
                  weightsPath = "weights/LeNetMNIST.temp.hdf5")

# compile the model
model.compile(optimizer = tf.keras.optimizers.SGD(learning_rate = 0.01),
             loss = "sparse_categorical_crossentropy",
             metrics = ["accuracy"])
# Out:
# [INFO] compiling model

# %%
# show the accuracy on the testing set
print("[INFO] Evaluating...")
(loss,accuracy)= model.evaluate(testData, testLabels, batch_size = 128, verbose=1)
print("[INFO] Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# [INFO] Evaluating...
# WARNING:tensorflow:From C:\Users\Hardik Gohil\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Hardik Gohil\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 79/79 [==============================] - 1s 4ms/step - loss: 0.0418 - accuracy: 0.9862
# [INFO] Accuracy: 98.62%

# %% [markdown]
# ## Model predictions

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

#set up matplotlb fig, and size it to fit 3x4 pics
nrows = 3
ncols = 4
fig = plt.gcf()
fig.set_size_inches(ncols*4,nrows*4)

# randomly select a few testing digits
num_predictions = 12
test_indices = np.random.choice(np.arange(0,len(testLabels)), size = (num_predictions,))
test_images = np.stack(([testData[i] for i in test_indices]))
test_labels = np.stack(([testLabels[i] for i in test_indices]))

# Compute predictions
predictions = model.predict(test_images)

for i in range(num_predictions):
    # select the most probable class
    prediction = np.argmax(predictions[i])
    
    # rescale the test image
    image = (test_images[i]*255).astype('uint8')
    
    # resize the  test image to see it better
    
    image = cv2.resize(image,(96,96), interpolation=cv2.INTER_CUBIC)
    
    # Convert grayscale to rgb color
    
    image = cv2.merge([image]*3)
    
    # Select prediction text color
    if prediction == test_labels[i]:
        rgb_color = (0,255,0)
    else:
        rgb_color = (255,0,0)
    
    # Show the image and prediction
    cv2.putText(image, str(prediction), (0,18), cv2.FONT_HERSHEY_SIMPLEX,0.75, rgb_color,1)
    
    # set up subplot; subplot indices start at 1
    sp = plt.subplot(nrows,ncols,i+1,title="label: %s" % test_labels[i])
    sp.axis('Off')
    plt.imshow(image)

plt.show()
# Out:
# 1/1 [==============================] - 0s 16ms/step

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
#      ---------------------------------------- 38.6/38.6 MB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.0 in c:\users\hardik gohil\anaconda3\lib\site-packages (from opencv-python) (1.25.0)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.9.0.80
